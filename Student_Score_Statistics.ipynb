# %%
import pandas as pd
from scipy.stats import shapiro, ttest_ind

# Load the previously saved CSV
df = pd.read_csv('/mnt/data/students_scores.csv')

# Display the DataFrame to the user
import ace_tools as tools; tools.display_dataframe_to_user(name="Student Gender and Scores Dataset", dataframe=df)

# Separate groups
female_scores = df[df['Gender'] == 'Female']['Score']
male_scores = df[df['Gender'] == 'Male']['Score']

# Shapiro-Wilk test for normality
stat_f, p_f = shapiro(female_scores)
stat_m, p_m = shapiro(male_scores)

print(f"Female group Shapiro-Wilk: statistic={stat_f:.4f}, p-value={p_f:.4f}")
print(f"Male   group Shapiro-Wilk: statistic={stat_m:.4f}, p-value={p_m:.4f}\n")

# Unpaired Student's t-test (Welch's t-test)
t_stat, p_val = ttest_ind(female_scores, male_scores, equal_var=False)
print(f"Unpaired t-test: t-statistic={t_stat:.4f}, p-value={p_val:.4f}")

if p_val < 0.05:
    print("Conclusion: Reject the null hypothesis. There is a significant difference in means.")
else:
    print("Conclusion: Fail to reject the null hypothesis. No significant difference in means.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-e480d7b3a51a> in <cell line: 0>()
#       3
#       4 # Load the previously saved CSV
# ----> 5 df = pd.read_csv('/mnt/data/students_scores.csv')
#       6
#       7 # Display the DataFrame to the user
#
# ...
